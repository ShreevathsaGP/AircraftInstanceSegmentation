# %% [markdown]
# ## INSTALL REQUIRED LIBRARIES

# %%
# !pip install ultralytics

# %% [markdown]
# ## TRAIN YOLOv8 MODEL

# %%
import os
from ultralytics import YOLO

model = YOLO("yolov8n-seg.pt")
model.train(data="/kaggle/input/aircraft-segmentation-data/aircraft_training_config.yaml", epochs=30, imgsz=640)

# %% [markdown]
# ## SAVE TRAINING WEIGHTS & RESULTS

# %%
import shutil
shutil.make_archive("something", 'zip', "/kaggle/working/runs")

# %%
# !rm -rf /kaggle/working/something.zip

# %%
import os
import subprocess
from IPython.display import FileLink, display

def download_file(path, download_file_name):
    zip_name = f"/kaggle/working/{download_file_name}.zip"
    command = f"zip {zip_name} {path} -r"
    result = subprocess.run(command, shell=True, capture_output=True, text=True)
    
    if result.returncode != 0:
        print("Unable to run zip command!")
        print(result.stderr)
        return
    
    display(FileLink(f'{download_file_name}.zip'))

# %%
download_file('/kaggle/working/runs', 'download')
